# %% [markdown]
# # Evaluation
#
# Evaluating `FP2MP-Eval` for every problem/solution pair

# %%
from fp2mp_eval.utils import read_json, write_json

results = read_json('data/results.json')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from Urbanomy.fp2mp_eval.utils import read_json, write_json
#       3 results = read_json('data/results.json')
#
# ModuleNotFoundError: No module named 'Urbanomy'

# %%
from tqdm import tqdm
from fp2mp_eval import FP2MPEval

N_JUDGES = 5

fp2mp = FP2MPEval(model='openai/gpt-4.1', n_judges=N_JUDGES)

for result in tqdm(results):
    problem = result['problem']
    solution = result['solution']
    evals = fp2mp.evaluate_case((problem, solution), max_workers=N_JUDGES)
    result['evaluations'] = [e.model_dump() for e in evals]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:39<04:36, 39.55s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [01:09<03:23, 33.99s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [01:39<02:41, 32.32s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  50%|█████     | 4/8 [02:12<02:09, 32.28s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  62%|██████▎   | 5/8 [02:43<01:35, 31.87s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  75%|███████▌  | 6/8 [03:08<00:59, 29.53s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  88%|████████▊ | 7/8 [03:54<00:35, 35.03s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [04:36<00:00, 34.58s/it]
